# %%
from ipython2cwl.iotypes import CWLFilePathInput, CWLFilePathOutput, CWLIntInput

# %%
input_value: 'CWLIntInput' = 5

# %%
result = input_value * 2

# %%
output_file: 'CWLFilePathOutput' = 'result.txt'
with open(output_file, 'w') as f:
    f.write(str(result))
